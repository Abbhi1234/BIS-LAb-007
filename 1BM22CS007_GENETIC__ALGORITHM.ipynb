# %% [markdown]
# <a href="https://colab.research.google.com/github/Abbhi1234/BIS-LAb-007/blob/main/1BM22CS007_GENETIC__ALGORITHM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Define the problem: maximize f(x) = x^2
def fitness_function(x):
    return x ** 2

# Initialize parameters
POPULATION_SIZE = 100
MUTATION_RATE = 0.01
CROSSOVER_RATE = 0.9
NUM_GENERATIONS = 50
X_RANGE = (-10, 10)  # The range for the x values

# Create an individual (a solution)
def create_individual():
    return random.uniform(X_RANGE[0], X_RANGE[1])

# Create the initial population
def create_population():
    return [create_individual() for _ in range(POPULATION_SIZE)]

# Evaluate the fitness of each individual
def evaluate_population(population):
    return [fitness_function(ind) for ind in population]

# Selection using roulette wheel method
def roulette_wheel_selection(population, fitness_values):
    total_fitness = sum(fitness_values)
    pick = random.uniform(0, total_fitness)
    current = 0
    for individual, fitness in zip(population, fitness_values):
        current += fitness
        if current > pick:
            return individual

# Crossover (linear crossover)
def crossover(parent1, parent2):
    if random.random() < CROSSOVER_RATE:
        alpha = random.random()  # Weighted combination
        offspring1 = alpha * parent1 + (1 - alpha) * parent2
        offspring2 = alpha * parent2 + (1 - alpha) * parent1
        return offspring1, offspring2
    else:
        return parent1, parent2

# Mutation
def mutate(individual):
    if random.random() < MUTATION_RATE:
        return random.uniform(X_RANGE[0], X_RANGE[1])
    return individual

# Genetic Algorithm function
def genetic_algorithm():
    # Step 1: Initialize the population
    population = create_population()

    for generation in range(NUM_GENERATIONS):
        # Step 2: Evaluate the fitness
        fitness_values = evaluate_population(population)

        # Track the best solution in this generation
        best_individual = population[fitness_values.index(max(fitness_values))]
        best_fitness = max(fitness_values)

        print(f"Generation {generation + 1}: Best Fitness = {best_fitness}, Best Individual = {best_individual}")

        # Step 3: Create a new population
        new_population = []

        while len(new_population) < POPULATION_SIZE:
            # Step 4: Selection
            parent1 = roulette_wheel_selection(population, fitness_values)
            parent2 = roulette_wheel_selection(population, fitness_values)

            # Step 5: Crossover
            offspring1, offspring2 = crossover(parent1, parent2)

            # Step 6: Mutation
            offspring1 = mutate(offspring1)
            offspring2 = mutate(offspring2)

            new_population.extend([offspring1, offspring2])

        # Step 7: Replacement with the new population
        population = new_population[:POPULATION_SIZE]  # Ensure population size is maintained

    # After all generations, return the best solution found
    fitness_values = evaluate_population(population)
    best_individual = population[fitness_values.index(max(fitness_values))]
    best_fitness = max(fitness_values)
    print(f"\nBest Solution: x = {best_individual}, f(x) = {best_fitness}")

# Run the genetic algorithm
if __name__ == "__main__":
    genetic_algorithm()
# Out:
# Generation 1: Best Fitness = 96.74292284816637, Best Individual = 9.83579802802835
# Generation 2: Best Fitness = 95.16436190801309, Best Individual = 9.7552222890108
# Generation 3: Best Fitness = 95.16436190801309, Best Individual = 9.7552222890108
# Generation 4: Best Fitness = 89.2450576993311, Best Individual = -9.446960235934684
# Generation 5: Best Fitness = 85.04088863998493, Best Individual = -9.221761688527032
# Generation 6: Best Fitness = 85.04088863998493, Best Individual = -9.221761688527032
# Generation 7: Best Fitness = 76.02538909241702, Best Individual = -8.719253929804832
# Generation 8: Best Fitness = 76.02538909241702, Best Individual = -8.719253929804832
# Generation 9: Best Fitness = 74.80074128574955, Best Individual = -8.648742179400976
# Generation 10: Best Fitness = 71.28993885471957, Best Individual = -8.443336950206332
# Generation 11: Best Fitness = 70.40704267981377, Best Individual = -8.390890458098816
# Generation 12: Best Fitness = 69.69223175911958, Best Individual = -8.348187333734167
# Generation 13: Best Fitness = 68.99024724634324, Best Individual = -8.306036795388234
# Generation 14: Best Fitness = 66.12008308415655, Best Individual = -8.131425648934911
# Generation 15: Best Fitness = 64.96710529081383, Best Individual = -8.06021744686915
# Generation 16: Best Fitness = 63.399095276609934, Best Individual = -7.96235488260916
# Generation 17: Best Fitness = 63.399095276609934, Best Individual = -7.96235488260916
# Generation 18: Best Fitness = 62.01404203793198, Best Individual = -7.874899493830507
# Generation 19: Best Fitness = 96.58445183524006, Best Individual = 9.827738897388354
# Generation 20: Best Fitness = 60.84773680525328, Best Individual = -7.8004959332886825
# Generation 21: Best Fitness = 60.63325061404179, Best Individual = -7.786735555676833
# Generation 22: Best Fitness = 60.543278011869006, Best Individual = -7.780956111678629
# Generation 23: Best Fitness = 60.231271852162784, Best Individual = -7.760880868314033
# Generation 24: Best Fitness = 60.062048405054966, Best Individual = -7.749970864787491
# Generation 25: Best Fitness = 86.83603303376641, Best Individual = 9.318585355823405
# Generation 26: Best Fitness = 59.770870965348585, Best Individual = -7.731162329517379
# Generation 27: Best Fitness = 59.63837872984393, Best Individual = -7.722588861893654
# Generation 28: Best Fitness = 59.548188553820495, Best Individual = -7.716747278084238
# Generation 29: Best Fitness = 59.53381617607738, Best Individual = -7.715815976037621
# Generation 30: Best Fitness = 59.42717664762813, Best Individual = -7.708902428207801
# Generation 31: Best Fitness = 71.19337082369313, Best Individual = 8.43761641837866
# Generation 32: Best Fitness = 94.88575787995983, Best Individual = 9.740932084762722
# Generation 33: Best Fitness = 59.2939108765524, Best Individual = -7.70025394883522
# Generation 34: Best Fitness = 59.2939108765524, Best Individual = -7.70025394883522
# Generation 35: Best Fitness = 96.51168965585246, Best Individual = -9.824036321993749
# Generation 36: Best Fitness = 96.23777993842538, Best Individual = -9.810085623399287
# Generation 37: Best Fitness = 96.23777993842538, Best Individual = -9.810085623399287
# Generation 38: Best Fitness = 85.23299094573578, Best Individual = -9.232171518431391
# Generation 39: Best Fitness = 80.86118161908132, Best Individual = -8.992284560615357
# Generation 40: Best Fitness = 78.05348999622518, Best Individual = -8.834788622045531
# Generation 41: Best Fitness = 76.7232084387179, Best Individual = -8.759178525336603
# Generation 42: Best Fitness = 93.72627001930098, Best Individual = 9.681232877030745
# Generation 43: Best Fitness = 93.72627001930098, Best Individual = 9.681232877030745
# Generation 44: Best Fitness = 72.9289012244376, Best Individual = -8.539841990601325
# Generation 45: Best Fitness = 71.92451904546043, Best Individual = -8.480832450028737
# Generation 46: Best Fitness = 70.79235708392285, Best Individual = -8.413819411178425
# Generation 47: Best Fitness = 70.78189684135528, Best Individual = -8.413197777382585
# Generation 48: Best Fitness = 70.0790730140282, Best Individual = -8.371324448020648
# Generation 49: Best Fitness = 69.79125427351674, Best Individual = -8.354116007903933
# Generation 50: Best Fitness = 93.53786542416725, Best Individual = 9.671497579184273
#
# Best Solution: x = -8.291291291945596, f(x) = 68.74551128789287
